# %% [markdown]
# # Mod 3 Final Project

# %% [markdown]
# ## Student Info
#
# - Name: Susanna Han
# - Cohort: Part Time
# - Instructor: James

# %% [markdown]
# ## Instructions:

# %% [markdown]
# - Open and read the project assignment and guidelines in `MOD_PROJECT_README.ipynb`
# - Review the hypothesis testing workflow found in this repo's `README.md` and inside `hypothesis_testing_workflow.ipynb` (also at the bottom of the `MOD_PROJECT_README.ipynb`)
#
# - 3 functions from study group/learn.co lessons have been provided inside `functions.py`
#     - `Cohen_d`, `find_outliers_IQR`,`find_outliers_Z`

# %% [markdown]
# <img src="https://raw.githubusercontent.com/jirvingphd/dsc-mod-3-project-online-ds-ft-100719/master/Northwind_ERD_updated.png">

# %% [markdown]
# # PROJECT

# %%
# !pip install -U fsds_100719
from fsds_100719.imports import *
import pandas as pd
# Out:
# fsds_1007219  v0.7.16 loaded.  Read the docs: https://fsds.readthedocs.io/en/latest/
# <style  type="text/css" >
# </style>
# <table id="T_bb796df4_60df_11ea_b020_acde48001122" ><caption>Loaded Packages and Handles</caption>
# <thead>    <tr>
#         <th class="col_heading level0 col0" >Handle</th>
#         <th class="col_heading level0 col1" >Package</th>
#         <th class="col_heading level0 col2" >Description</th>
#     </tr></thead>
# <tbody>    <tr>
#         <td id="T_bb796df4_60df_11ea_b020_acde48001122row0_col0" class="data row0 col0" >dp</td>
#         <td id="T_bb796df4_60df_11ea_b020_acde48001122row0_col1" class="data row0 col1" >IPython.display</td>
#         <td id="T_bb796df4_60df_11ea_b020_acde48001122row0_col2" class="data row0 col2" >Display modules with helpful display and clearing commands.</td>
#     </tr>    <tr>
#         <td id="T_bb796df4_60df_11ea_b020_acde48001122row1_col0" class="data row1 col0" >fs</td>
#         <td id="T_bb796df4_60df_11ea_b020_acde48001122row1_col1" class="data row1 col1" >fsds_100719</td>
#         <td id="T_bb796df4_60df_11ea_b020_acde48001122row1_col2" class="data row1 col2" >Custom data science bootcamp student package</td>
#     </tr>    <tr>
#         <td id="T_bb796df4_60df_11ea_b020_acde48001122row2_col0" class="data row2 col0" >mpl</td>
#         <td id="T_bb796df4_60df_11ea_b020_acde48001122row2_col1" class="data row2 col1" >matplotlib</td>
#         <td id="T_bb796df4_60df_11ea_b020_acde48001122row2_col2" class="data row2 col2" >Matplotlib's base OOP module with formatting artists</td>
#     </tr>    <tr>
#         <td id="T_bb796df4_60df_11ea_b020_acde48001122row3_col0" class="data row3 col0" >plt</td>
#         <td id="T_bb796df4_60df_11ea_b020_acde48001122row3_col1" class="data row3 col1" >matplotlib.pyplot</td>
#         <td id="T_bb796df4_60df_11ea_b020_acde48001122row3_col2" class="data row3 col2" >Matplotlib's matlab-like plotting module</td>
#     </tr>    <tr>
#         <td id="T_bb796df4_60df_11ea_b020_acde48001122row4_col0" class="data row4 col0" >np</td>
#         <td id="T_bb796df4_60df_11ea_b020_acde48001122row4_col1" class="data row4 col1" >numpy</td>
#         <td id="T_bb796df4_60df_11ea_b020_acde48001122row4_col2" class="data row4 col2" >scientific computing with Python</td>
#     </tr>    <tr>
#         <td id="T_bb796df4_60df_11ea_b020_acde48001122row5_col0" class="data row5 col0" >pd</td>
#         <td id="T_bb796df4_60df_11ea_b020_acde48001122row5_col1" class="data row5 col1" >pandas</td>
#         <td id="T_bb796df4_60df_11ea_b020_acde48001122row5_col2" class="data row5 col2" >High performance data structures and tools</td>
#     </tr>    <tr>
#         <td id="T_bb796df4_60df_11ea_b020_acde48001122row6_col0" class="data row6 col0" >sns</td>
#         <td id="T_bb796df4_60df_11ea_b020_acde48001122row6_col1" class="data row6 col1" >seaborn</td>
#         <td id="T_bb796df4_60df_11ea_b020_acde48001122row6_col2" class="data row6 col2" >High-level data visualization library based on matplotlib</td>
#     </tr></tbody>
# </table>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# [i] Pandas .iplot() method activated.

# %%
import pandas as pd
import scipy.stats as stats
import pandas as pd
import numpy as np
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
def Cohen_d(group1, group2, correction = False):
    """Compute Cohen's d
    d = (group1.mean()-group2.mean())/pool_variance.
    pooled_variance= (n1 * var1 + n2 * var2) / (n1 + n2)

    Args:
        group1 (Series or NumPy array): group 1 for calculating d
        group2 (Series or NumPy array): group 2 for calculating d
        correction (bool): Apply equation correction if N<50. Default is False. 
            - Url with small ncorrection equation: 
                - https://www.statisticshowto.datasciencecentral.com/cohens-d/ 
    Returns:
        d (float): calculated d value
         
    INTERPRETATION OF COHEN's D: 
    > Small effect = 0.2
    > Medium Effect = 0.5
    > Large Effect = 0.8
    
    """
    import scipy.stats as stats
    import scipy   
    import numpy as np
    N = len(group1)+len(group2)
    diff = group1.mean() - group2.mean()

    n1, n2 = len(group1), len(group2)
    var1 = group1.var()
    var2 = group2.var()

    # Calculate the pooled threshold as shown earlier
    pooled_var = (n1 * var1 + n2 * var2) / (n1 + n2)
    
    # Calculate Cohen's d statistic
    d = diff / np.sqrt(pooled_var)
    
    ## Apply correction if needed
    if (N < 50) & (correction==True):
        d=d * ((N-3)/(N-2.25))*np.sqrt((N-2)/N)
    return d


#Your code here
def find_outliers_z(data):
    """Use scipy to calculate absolute Z-scores 
    and return boolean series where True indicates it is an outlier.

    Args:
        data (Series,or ndarray): data to test for outliers.

    Returns:
        [boolean Series]: A True/False for each row use to slice outliers.
        
    EXAMPLE USE: 
    >> idx_outs = find_outliers_df(df['AdjustedCompensation'])
    >> good_data = df[~idx_outs].copy()
    """
    import pandas as pd
    import numpy as np
    import scipy.stats as stats
    import pandas as pd
    import numpy as np
    ## Calculate z-scores
    zs = stats.zscore(data)
    
    ## Find z-scores >3 awayfrom mean
    idx_outs = np.abs(zs)>3
    
    ## If input was a series, make idx_outs index match
    if isinstance(data,pd.Series):
        return pd.Series(idx_outs,index=data.index)
    else:
        return pd.Series(idx_outs)
    
    
    
def find_outliers_IQR(data):
    """Use Tukey's Method of outlier removal AKA InterQuartile-Range Rule
    and return boolean series where True indicates it is an outlier.
    - Calculates the range between the 75% and 25% quartiles
    - Outliers fall outside upper and lower limits, using a treshold of  1.5*IQR the 75% and 25% quartiles.

    IQR Range Calculation:    
        res = df.describe()
        IQR = res['75%'] -  res['25%']
        lower_limit = res['25%'] - 1.5*IQR
        upper_limit = res['75%'] + 1.5*IQR

    Args:
        data (Series,or ndarray): data to test for outliers.

    Returns:
        [boolean Series]: A True/False for each row use to slice outliers.
        
    EXAMPLE USE: 
    >> idx_outs = find_outliers_df(df['AdjustedCompensation'])
    >> good_data = df[~idx_outs].copy()
    
    """
    df_b=data
    res= df_b.describe()

    IQR = res['75%'] -  res['25%']
    lower_limit = res['25%'] - 1.5*IQR
    upper_limit = res['75%'] + 1.5*IQR

    idx_outs = (df_b>upper_limit) | (df_b<lower_limit)

    return idx_outs



def prep_data_for_tukeys(data):
    """Accepts a dictionary with group names as the keys 
    and pandas series as the values. 
    
    Returns a dataframe ready for tukeys test:
    - with a 'data' column and a 'group' column for sms.stats.multicomp.pairwise_tukeyhsd 
    
    Example Use:
    df_tukey = prep_data_for_tukeys(grp_data)
    tukey = sms.stats.multicomp.pairwise_tukeyhsd(df_tukey['data'], df_tukey['group'])
    tukey.summary()
    """
    
    df_tukey = pd.DataFrame(columns=['data','group'])
    for k,v in  data.items():
        grp_df = v.rename('data').to_frame() 
        grp_df['group'] = k
        df_tukey=pd.concat([df_tukey, grp_df],axis=0)

	## New lines added to ensure compatibility with tukey's test
    df_tukey['group'] = df_tukey['group'].astype('str')
    df_tukey['data'] = df_tukey['data'].astype('float')
    return df_tukey

# %%
import sqlite3
connect = sqlite3.connect('Northwind_small.sqlite')
cur = connect.cursor()

# %%
## To see all tables
cur.execute("""SELECT name FROM sqlite_master WHERE type='table';""")
df_tables = pd.DataFrame(cur.fetchall(), columns=['Table'])
df_tables
# Out:
#                    Table
# 0               Employee
# 1               Category
# 2               Customer
# 3                Shipper
# 4               Supplier
# 5                  Order
# 6                Product
# 7            OrderDetail
# 8   CustomerCustomerDemo
# 9    CustomerDemographic
# 10                Region
# 11             Territory
# 12     EmployeeTerritory

# %% [markdown]
# # Hypothesis 1

# %% [markdown]
# > Does discount amount have a statistically significant effect on the quantity of a product in an order? If so, at what level(s) of discount?
#
# - $H_0$: The customer orders the same quantity of a product whether it's discounted or full price.
# - $H_A$: The customer orders more or less of a product whether it's discounted or full price.

# %%
cur.execute('''SELECT * from OrderDetail''')
col_names = [x[0] for x in cur.description]
col_names
# Out:
# ['Id', 'OrderId', 'ProductId', 'UnitPrice', 'Quantity', 'Discount']

# %%
df = pd.DataFrame(cur.fetchall(), columns = col_names)
df.head()
# Out:
#          Id  OrderId  ProductId  UnitPrice  Quantity  Discount
# 0  10248/11    10248         11       14.0        12       0.0
# 1  10248/42    10248         42        9.8        10       0.0
# 2  10248/72    10248         72       34.8         5       0.0
# 3  10249/14    10249         14       18.6         9       0.0
# 4  10249/51    10249         51       42.4        40       0.0

# %% [markdown]
# A discount group column was created to translate the bool into words to define the content in a more clear way. (Discounted or Full Price)

# %%
df['Discount_grp'] = df['Discount'] > 0
df['Discount_grp'] = df['Discount_grp'].map({True:'Discounted', False: 'Full Price'})
df
# Out:
#             Id  OrderId  ProductId  UnitPrice  Quantity  Discount Discount_grp
# 0     10248/11    10248         11      14.00        12      0.00   Full Price
# 1     10248/42    10248         42       9.80        10      0.00   Full Price
# 2     10248/72    10248         72      34.80         5      0.00   Full Price
# 3     10249/14    10249         14      18.60         9      0.00   Full Price
# 4     10249/51    10249         51      42.40        40      0.00   Full Price
# 5     10250/41    10250         41       7.70        10      0.00   Full Price
# 6     10250/51    10250         51      42.40        35      0.15   Discounted
# 7     10250/65    10250         65      16.80        15      0.15   Discounted
# 8     10251/22    10251         22      16.80         6      0.05   Discounted
# 9     10251/57    10251         57      15.60        15      0.05   Discounted
# 10    10251/65    10251         65      16.80        20      0.00   Full Price
# 11    10252/20    10252         20      64.80        40      0.05   Discounted
# 12    10252/33    10252         33       2.00        25      0.05   Discounted
# 13    10252/60    10252         60      27.20        40      0.00   Full Price
# 14    10253/31    10253         31      10.00        20      0.00   Full Price
# 15    10253/39    10253         39      14.40        42      0.00   Full Price
# 16    10253/49    10253         49      16.00        40      0.00   Full Price
# 17    10254/24    10254         24       3.60        15      0.15   Discounted
# 18    10254/55    10254         55      19.20        21      0.15   Discounted
# 19    10254/74    10254         74       8.00        21      0.00   Full Price
# 20     10255/2    10255          2      15.20        20      0.00   Full Price
# 21    10255/16    10255         16      13.90        35      0.00   Full Price
# 22    10255/36    10255         36      15.20        25      0.00   Full Price
# 23    10255/59    10255         59      44.00        30      0.00   Full Price
# 24    10256/53    10256         53      26.20        15      0.00   Full Price
# 25    10256/77    10256         77      10.40        12      0.00   Full Price
# 26    10257/27    10257         27      35.10        25      0.00   Full Price
# 27    10257/39    10257         39      14.40         6      0.00   Full Price
# 28    10257/77    10257         77      10.40        15      0.00   Full Price
# 29     10258/2    10258          2      15.20        50      0.20   Discounted
# ...        ...      ...        ...        ...       ...       ...          ...
# 2125  11075/46    11075         46      12.00        30      0.15   Discounted
# 2126  11075/76    11075         76      18.00         2      0.15   Discounted
# 2127   11076/6    11076          6      25.00        20      0.25   Discounted
# 2128  11076/14    11076         14      23.25        20      0.25   Discounted
# 2129  11076/19    11076         19       9.20        10      0.25   Discounted
# 2130   11077/2    11077          2      19.00        24      0.20   Discounted
# 2131   11077/3    11077          3      10.00         4      0.00   Full Price
# 2132   11077/4    11077          4      22.00         1      0.00   Full Price
# 2133   11077/6    11077          6      25.00         1      0.02   Discounted
# 2134   11077/7    11077          7      30.00         1      0.05   Discounted
# 2135   11077/8    11077          8      40.00         2      0.10   Discounted
# 2136  11077/10    11077         10      31.00         1      0.00   Full Price
# 2137  11077/12    11077         12      38.00         2      0.05   Discounted
# 2138  11077/13    11077         13       6.00         4      0.00   Full Price
# 2139  11077/14    11077         14      23.25         1      0.03   Discounted
# 2140  11077/16    11077         16      17.45         2      0.03   Discounted
# 2141  11077/20    11077         20      81.00         1      0.04   Discounted
# 2142  11077/23    11077         23       9.00         2      0.00   Full Price
# 2143  11077/32    11077         32      32.00         1      0.00   Full Price
# 2144  11077/39    11077         39      18.00         2      0.05   Discounted
# 2145  11077/41    11077         41       9.65         3      0.00   Full Price
# 2146  11077/46    11077         46      12.00         3      0.02   Discounted
# 2147  11077/52    11077         52       7.00         2      0.00   Full Price
# 2148  11077/55    11077         55      24.00         2      0.00   Full Price
# 2149  11077/60    11077         60      34.00         2      0.06   Discounted
# 2150  11077/64    11077         64      33.25         2      0.03   Discounted
# 2151  11077/66    11077         66      17.00         1      0.00   Full Price
# 2152  11077/73    11077         73      15.00         2      0.01   Discounted
# 2153  11077/75    11077         75       7.75         4      0.00   Full Price
# 2154  11077/77    11077         77      13.00         2      0.00   Full Price
#
# [2155 rows x 7 columns]

# %% [markdown]
# Created a bar graph comparing the different discount amounts with the number of products bought to see a general comparison.

# %%
sns.barplot(data=df, x = df['Discount'], y= df['Quantity'], ci=68);

# %%
discounts = {}
for discount_grps in df['Discount'].unique():
    discounts[discount_grps]= df.groupby('Discount').get_group(discount_grps)['Quantity']
discounts
# Out:
# {0.0: 0        12
#  1        10
#  2         5
#  3         9
#  4        40
#  5        10
#  10       20
#  13       40
#  14       20
#  15       42
#  16       40
#  19       21
#  20       20
#  21       35
#  22       25
#  23       30
#  24       15
#  25       12
#  26       25
#  27        6
#  28       15
#  32       10
#  33        1
#  35       50
#  38       20
#  39       20
#  41       15
#  42        2
#  44       28
#  47       35
#         ...
#  2088      4
#  2089     10
#  2090     15
#  2093     30
#  2097     12
#  2100     55
#  2103      3
#  2104     42
#  2105     35
#  2106      9
#  2110     20
#  2114     20
#  2117      8
#  2118     40
#  2119     22
#  2120    130
#  2121     10
#  2122     20
#  2131      4
#  2132      1
#  2136      1
#  2138      4
#  2142      2
#  2143      1
#  2145      3
#  2147      2
#  2148      2
#  2151      1
#  2153      4
#  2154      2
#  Name: Quantity, Length: 1317, dtype: int64, 0.15: 6       35
#  7       15
#  17      15
#  18      21
#  48      25
#  53      70
#  54      15
#  104     40
#  106     15
#  196     21
#  197     70
#  199     40
#  200     80
#  220     50
#  221     25
#  250      9
#  266     50
#  268      6
#  269     15
#  279     20
#  326     15
#  328     20
#  341     20
#  342     20
#  397     10
#  398     18
#  414     21
#  415     70
#  463      4
#  465     15
#          ..
#  1757    12
#  1774    42
#  1793    10
#  1794    40
#  1829    28
#  1830    25
#  1832    24
#  1843    20
#  1853     2
#  1859    12
#  1860    12
#  1882    20
#  1883    40
#  1885     6
#  1896    84
#  1917    60
#  1918    65
#  1919    66
#  1948    15
#  1949    24
#  1993    24
#  2107     8
#  2108    36
#  2109    28
#  2111    40
#  2112    20
#  2113    30
#  2124    10
#  2125    30
#  2126     2
#  Name: Quantity, Length: 157, dtype: int64, 0.05: 8         6
#  9        15
#  11       40
#  12       25
#  51       12
#  57       60
#  58       20
#  65       24
#  66       15
#  68       60
#  69       33
#  72       12
#  73        6
#  216      10
#  217       8
#  218      20
#  219      12
#  244      70
#  246      20
#  247      12
#  248      40
#  256       4
#  274      20
#  276      77
#  277      10
#  292      10
#  293      10
#  294      20
#  295      56
#  296      70
#         ...
#  1691    120
#  1712     20
#  1715     20
#  1716     14
#  1822     15
#  1823      6
#  1824     50
#  1825     16
#  1827     50
#  1828     50
#  1846      6
#  1926     18
#  1937     20
#  1938     15
#  1939     21
#  1963     70
#  1964     90
#  1971     40
#  1973     50
#  1974     36
#  1975     60
#  2057     20
#  2058     15
#  2059     18
#  2115     15
#  2116     10
#  2123     14
#  2134      1
#  2137      2
#  2144      2
#  Name: Quantity, Length: 185, dtype: int64, 0.2: 29      50
#  30      65
#  31       6
#  40      12
#  99      45
#  100     40
#  101     36
#  209     25
#  210     50
#  211     35
#  212     30
#  223     40
#  224     10
#  225     16
#  231      7
#  232     25
#  233      6
#  234     48
#  251     24
#  252     56
#  253     40
#  254     40
#  280     12
#  281     50
#  289     30
#  291      8
#  329      6
#  334     80
#  335     50
#  362     10
#          ..
#  1572    36
#  1573    45
#  1574    55
#  1656    30
#  1657    30
#  1658    50
#  1750    10
#  1751    10
#  1752    24
#  1772    25
#  1773    30
#  1786    30
#  1833    12
#  1867    40
#  1892    40
#  1920    50
#  1921    20
#  1922    90
#  2041     5
#  2049    30
#  2063    10
#  2064     4
#  2066    10
#  2067    30
#  2068    10
#  2069    35
#  2071    25
#  2091    10
#  2092    12
#  2130    24
#  Name: Quantity, Length: 161, dtype: int64, 0.25: 34       16
#  36       15
#  37       21
#  43       60
#  45       60
#  46       36
#  82       15
#  95       15
#  97       20
#  98        5
#  135      40
#  136      30
#  259      70
#  325      18
#  330      12
#  331      40
#  332      70
#  333      42
#  384      25
#  385      42
#  386       7
#  387      70
#  450       2
#  451      36
#  473      10
#  474      20
#  480      35
#  485      50
#  486      50
#  487      30
#         ...
#  1791     49
#  1792     35
#  1797     44
#  1798     30
#  1799     80
#  1805      5
#  1806     18
#  1844     10
#  1924     50
#  1925     35
#  1931     20
#  1932     20
#  1940     25
#  1941     30
#  1959      2
#  1967     18
#  1994     11
#  1997     44
#  2011     30
#  2012     21
#  2017    100
#  2019     60
#  2020    100
#  2060     25
#  2061     30
#  2101      4
#  2102     20
#  2127     20
#  2128     20
#  2129     10
#  Name: Quantity, Length: 154, dtype: int64, 0.1: 107     10
#  108      3
#  115     20
#  116     24
#  117      2
#  147     40
#  148     30
#  149     15
#  153     25
#  154     25
#  155     30
#  177     40
#  178     30
#  179     25
#  227     10
#  228     40
#  235     18
#  263     36
#  272     15
#  273     18
#  303     54
#  304     55
#  320      5
#  321     13
#  323     35
#  344      8
#  345     16
#  346     20
#  347     18
#  348     20
#          ..
#  1547    30
#  1548    15
#  1561    70
#  1562    25
#  1563    42
#  1564    60
#  1628    42
#  1646    21
#  1753    20
#  1754    30
#  1776    30
#  1777    14
#  1779    20
#  1901    36
#  1902     8
#  1903    35
#  1912    40
#  1980    28
#  2007    10
#  2008    20
#  2029    70
#  2030    36
#  2031    15
#  2065    50
#  2094    40
#  2095    30
#  2096    77
#  2098    25
#  2099     4
#  2135     2
#  Name: Quantity, Length: 173, dtype: int64, 0.02: 2133    1
#  2146    3
#  Name: Quantity, dtype: int64, 0.03: 2139    1
#  2140    2
#  2150    2
#  Name: Quantity, dtype: int64, 0.04: 2141    1
#  Name: Quantity, dtype: int64, 0.06: 2149    2
#  Name: Quantity, dtype: int64, 0.01: 2152    2
#  Name: Quantity, dtype: int64}

# %% [markdown]
# The different amount of products are then grouped into the same discount categories as seen above. The graph below shows us a general distribution of the number of products sold at a certain discount percentage.

# %%
fig, ax=plt.subplots(figsize = (8,5))
for discount_grps, grp_data in discounts.items():
    sns.distplot(grp_data, label=discount_grps, ax=ax)
ax.legend()
ax.set(title ='Quantity by Discounted Group', ylabel = 'Density');

# %%
for discount_grps, grp_data in discounts.items():
    idx_outs = find_outliers_z(grp_data)
    print(f'I found {idx_outs.sum()} outliers in {discount_grps} using z-scores')
    discounts[discount_grps] = grp_data[-idx_outs]
# Out:
# I found 20 outliers in 0.0 using z-scores
# I found 2 outliers in 0.15 using z-scores
# I found 3 outliers in 0.05 using z-scores
# I found 2 outliers in 0.2 using z-scores
# I found 3 outliers in 0.25 using z-scores
# I found 3 outliers in 0.1 using z-scores
# I found 0 outliers in 0.02 using z-scores
# I found 0 outliers in 0.03 using z-scores
# I found 0 outliers in 0.04 using z-scores
# I found 0 outliers in 0.06 using z-scores
# I found 0 outliers in 0.01 using z-scores

# %% [markdown]
# All the outliers that were found above using the z-scores function are then taken out. We can see a slightly more normal distribution in our graph below.

# %%
fig, ax=plt.subplots(figsize = (8,5))
for discount_grps, grp_data in discounts.items():
    sns.distplot(grp_data, label=discount_grps, ax=ax )
ax.legend()
ax.set(title ='Quantity by Discounted Group', ylabel = 'Density');

# %%
for k,v in discounts.items():
    if len(v) > 8: 
        stat,p = stats.normaltest(v)
        print(f"The {k} Normaltest p-value = {round(p,4)}")
    else: 
        print(f"The column {k} is too small.")
# Out:
# The 0.0 Normaltest p-value = 0.0
# The 0.15 Normaltest p-value = 0.0
# The 0.05 Normaltest p-value = 0.0
# The 0.2 Normaltest p-value = 0.0005
# The 0.25 Normaltest p-value = 0.0013
# The 0.1 Normaltest p-value = 0.0
# The column 0.02 is too small.
# The column 0.03 is too small.
# The column 0.04 is too small.
# The column 0.06 is too small.
# The column 0.01 is too small.

# %%
toosmall = (0.02, 0.03, 0.04, 0.06, 0.01)
for key in toosmall:
    discounts.pop(key)

# %%
for k,v in discounts.items():
    print(f"There are {len(v)} in group {k}.")
# Out:
# There are 1297 in group 0.0.
# There are 155 in group 0.15.
# There are 182 in group 0.05.
# There are 159 in group 0.2.
# There are 151 in group 0.25.
# There are 170 in group 0.1.

# %% [markdown]
# The discount percentages with not enough data are then taken out of the dataset. The other discount categories that have more than 8 data points are shown with a p-value < 0.05 Therefore the data is not normal but since the size of our data is big enough to ignore the results of the normal test. The equal variance is able to be tested by using the levene's test.

# %%
data = []
for k,v in discounts.items():
    data.append(v)
data[0]
# Out:
# 0       12
# 1       10
# 2        5
# 3        9
# 4       40
# 5       10
# 10      20
# 13      40
# 14      20
# 15      42
# 16      40
# 19      21
# 20      20
# 21      35
# 22      25
# 23      30
# 24      15
# 25      12
# 26      25
# 27       6
# 28      15
# 32      10
# 33       1
# 35      50
# 38      20
# 39      20
# 41      15
# 42       2
# 44      28
# 47      35
#         ..
# 2087    35
# 2088     4
# 2089    10
# 2090    15
# 2093    30
# 2097    12
# 2100    55
# 2103     3
# 2104    42
# 2105    35
# 2106     9
# 2110    20
# 2114    20
# 2117     8
# 2118    40
# 2119    22
# 2121    10
# 2122    20
# 2131     4
# 2132     1
# 2136     1
# 2138     4
# 2142     2
# 2143     1
# 2145     3
# 2147     2
# 2148     2
# 2151     1
# 2153     4
# 2154     2
# Name: Quantity, Length: 1297, dtype: int64

# %%
stat,p = stats.levene(*data) 
print(f"Levene's test for equal variance p-value ={round(p,4)} therefore it does not have equal variance.")
# Out:
# Levene's test for equal variance p-value =0.0003 therefore it does not have equal variance.

# %% [markdown]
# To test the hypothesis the Kruskal-Wallis method is used to calculate the p-value.

# %%
stat,p = stats.kruskal(*data)
print(f'Kruskal-Wallis t-test p-value ={round(p,4)} therefore the alternative hypothesis is statistically significance.')
# Out:
# Kruskal-Wallis t-test p-value =0.0 therefore the alternative hypothesis is statistically significance.

# %% [markdown]
# With multiple different discount percentages a tukey's test is done to see which groups were significantly different between the amount of items sold correlated with at which the discount was given.

# %%
df_tukeys = prep_data_for_tukeys(discounts)
df_tukeys.head()
df_tukeys.columns = ['Quantity','Discount']

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
model= pairwise_tukeyhsd(df_tukeys['Quantity'],df_tukeys['Discount'])
model.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
sns.barplot(data=df, x = df_tukeys['Discount'], y= df_tukeys['Quantity'], ci=68);

# %% [markdown]
# It is statistically significant that the customers order more of a product when it is discounted than when it is at full price. It doesn't necessarily matter at what percentage the discount is made.

# %% [markdown]
# # Hypothesis 2

# %% [markdown]
# > Does discount have a statistically significant effect on the total amount spent in an order?
#
# - $H_0$: The customer spends the same amount of money whether it's discounted or full price.
# - $H_A$: The customer spends more or less money whether it's discounted or full price.

# %% [markdown]
# To find the total amount spent on an order we multiply the unit price by the number of items bought.

# %%
df['Total Spent'] = df['UnitPrice'] * df['Quantity']
df
# Out:
#             Id  OrderId  ProductId  UnitPrice  Quantity  Discount  \
# 0     10248/11    10248         11      14.00        12      0.00
# 1     10248/42    10248         42       9.80        10      0.00
# 2     10248/72    10248         72      34.80         5      0.00
# 3     10249/14    10249         14      18.60         9      0.00
# 4     10249/51    10249         51      42.40        40      0.00
# 5     10250/41    10250         41       7.70        10      0.00
# 6     10250/51    10250         51      42.40        35      0.15
# 7     10250/65    10250         65      16.80        15      0.15
# 8     10251/22    10251         22      16.80         6      0.05
# 9     10251/57    10251         57      15.60        15      0.05
# 10    10251/65    10251         65      16.80        20      0.00
# 11    10252/20    10252         20      64.80        40      0.05
# 12    10252/33    10252         33       2.00        25      0.05
# 13    10252/60    10252         60      27.20        40      0.00
# 14    10253/31    10253         31      10.00        20      0.00
# 15    10253/39    10253         39      14.40        42      0.00
# 16    10253/49    10253         49      16.00        40      0.00
# 17    10254/24    10254         24       3.60        15      0.15
# 18    10254/55    10254         55      19.20        21      0.15
# 19    10254/74    10254         74       8.00        21      0.00
# 20     10255/2    10255          2      15.20        20      0.00
# 21    10255/16    10255         16      13.90        35      0.00
# 22    10255/36    10255         36      15.20        25      0.00
# 23    10255/59    10255         59      44.00        30      0.00
# 24    10256/53    10256         53      26.20        15      0.00
# 25    10256/77    10256         77      10.40        12      0.00
# 26    10257/27    10257         27      35.10        25      0.00
# 27    10257/39    10257         39      14.40         6      0.00
# 28    10257/77    10257         77      10.40        15      0.00
# 29     10258/2    10258          2      15.20        50      0.20
# ...        ...      ...        ...        ...       ...       ...
# 2125  11075/46    11075         46      12.00        30      0.15
# 2126  11075/76    11075         76      18.00         2      0.15
# 2127   11076/6    11076          6      25.00        20      0.25
# 2128  11076/14    11076         14      23.25        20      0.25
# 2129  11076/19    11076         19       9.20        10      0.25
# 2130   11077/2    11077          2      19.00        24      0.20
# 2131   11077/3    11077          3      10.00         4      0.00
# 2132   11077/4    11077          4      22.00         1      0.00
# 2133   11077/6    11077          6      25.00         1      0.02
# 2134   11077/7    11077          7      30.00         1      0.05
# 2135   11077/8    11077          8      40.00         2      0.10
# 2136  11077/10    11077         10      31.00         1      0.00
# 2137  11077/12    11077         12      38.00         2      0.05
# 2138  11077/13    11077         13       6.00         4      0.00
# 2139  11077/14    11077         14      23.25         1      0.03
# 2140  11077/16    11077         16      17.45         2      0.03
# 2141  11077/20    11077         20      81.00         1      0.04
# 2142  11077/23    11077         23       9.00         2      0.00
# 2143  11077/32    11077         32      32.00         1      0.00
# 2144  11077/39    11077         39      18.00         2      0.05
# 2145  11077/41    11077         41       9.65         3      0.00
# 2146  11077/46    11077         46      12.00         3      0.02
#  Name: Total Spent, dtype: float64}

# %%
fig, ax=plt.subplots(figsize = (8,5))
for discount_grps, grp_data in discounts.items():
    sns.distplot(grp_data, label=discount_grps, ax=ax )
ax.legend()
ax.set(title ='Total Spent by Discounted Group', ylabel = 'Density');

# %%
for discount_grps, grp_data in discounts.items():
    idx_outs = find_outliers_z(grp_data)
    print(f'I found {idx_outs.sum()} outliers in {discount_grps} using z-scores')
    discounts[discount_grps] = grp_data[-idx_outs]
# Out:
# I found 19 outliers in 0.0 using z-scores
# I found 5 outliers in 0.15 using z-scores
# I found 3 outliers in 0.05 using z-scores
# I found 2 outliers in 0.2 using z-scores
# I found 6 outliers in 0.25 using z-scores
# I found 3 outliers in 0.1 using z-scores
# I found 0 outliers in 0.02 using z-scores
# I found 0 outliers in 0.03 using z-scores
# I found 0 outliers in 0.04 using z-scores
# I found 0 outliers in 0.06 using z-scores
# I found 0 outliers in 0.01 using z-scores

# %%
fig, ax=plt.subplots(figsize = (8,5))
for discount_grps, grp_data in discounts.items():
    sns.distplot(grp_data, label=discount_grps, ax=ax )
ax.legend()
ax.set(title ='Total Spent by Discounted Group', ylabel = 'Density');

# %%
for k,v in discounts.items():
    if len(v) > 8: 
        stat,p = stats.normaltest(v)
        print(f"The {k} Normaltest p-value = {round(p,4)}")
    else: 
        print(f"The column {k} is too small.")
# Out:
# The 0.0 Normaltest p-value = 0.0
# The 0.15 Normaltest p-value = 0.0
# The 0.05 Normaltest p-value = 0.0
# The 0.2 Normaltest p-value = 0.0
# The 0.25 Normaltest p-value = 0.0
# The 0.1 Normaltest p-value = 0.0
# The column 0.02 is too small.
# The column 0.03 is too small.
# The column 0.04 is too small.
# The column 0.06 is too small.
# The column 0.01 is too small.

# %%
toosmall = (0.02, 0.03, 0.04, 0.06, 0.01)
for key in toosmall:
    discounts.pop(key)

# %%
for k,v in discounts.items():
    print(f"There are {len(v)} in group {k}")
# Out:
# There are 1298 in group 0.0
# There are 152 in group 0.15
# There are 182 in group 0.05
# There are 159 in group 0.2
# There are 148 in group 0.25
# There are 170 in group 0.1

# %%
data = []
for k,v in discounts.items():
    data.append(v)
data[0]
# Out:
# 0        168.00
# 1         98.00
# 2        174.00
# 3        167.40
# 4       1696.00
# 5         77.00
# 10       336.00
# 13      1088.00
# 14       200.00
# 15       604.80
# 16       640.00
# 19       168.00
# 20       304.00
# 21       486.50
# 22       380.00
# 23      1320.00
# 24       393.00
# 25       124.80
# 26       877.50
# 27        86.40
# 28       156.00
# 32        80.00
# 33        20.80
# 35       780.00
# 38       160.00
# 39       288.00
# 41       360.00
# 42        60.80
# 44       100.80
# 47       532.00
#          ...
# 2087    1190.00
# 2088     136.00
# 2089     130.00
# 2090     510.00
# 2093     420.00
# 2097     115.80
# 2100     687.50
# 2103      52.35
# 2104     386.40
# 2105     490.00
# 2106      86.85
# 2110     360.00
# 2114     250.00
# 2117     152.00
# 2118     386.00
# 2119     357.50
# 2121     210.00
# 2122      90.00
# 2131      40.00
# 2132      22.00
# 2136      31.00
# 2138      24.00
# 2142      18.00
# 2143      32.00
# 2145      28.95
# 2147      14.00
# 2148      48.00
# 2151      17.00
# 2153      31.00
# 2154      26.00
# Name: Total Spent, Length: 1298, dtype: float64

# %%
stat,p = stats.levene(*data) 
print(f'Levenes test for equal variance p-value ={round(p,4)} therefore it does not have equal variance.')
# Out:
# Levenes test for equal variance p-value =0.0025 therefore it does not have equal variance.

# %%
stat,p = stats.kruskal(*data)
print(f'Kruskal-Wallis t-test p-value ={round(p,4)} therefore the alternative hypothesis is statistically significance.')
# Out:
# Kruskal-Wallis t-test p-value =0.0 therefore the alternative hypothesis is statistically significance.

# %%
df_tukeys = prep_data_for_tukeys(discounts)
df_tukeys.head()
df_tukeys.columns = ['Total Spent','Discount']

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
model= pairwise_tukeyhsd(df_tukeys['Total Spent'],df_tukeys['Discount'])
model.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
sns.barplot(data=df, x = df_tukeys['Discount'], y= df_tukeys['Total Spent'], ci=68);

# %% [markdown]
# # Hypothesis 3

# %% [markdown]
# > Does the supplier region have a statistically significant effect on the product quantity sold.
#
# - $H_0$: The supplier region does not have an effect on the product quantity sold.
# - $H_A$: THe supplier region does have an effect on the product quantity sold.

# %%
cur.execute('''SELECT *
               FROM "Order";''')
col_names = [x[0] for x in cur.description]
col_names
# Out:
# ['Id',
#  'CustomerId',
#  'EmployeeId',
#  'OrderDate',
#  'RequiredDate',
#  'ShippedDate',
#  'ShipVia',
#  'Freight',
#  'ShipName',
#  'ShipAddress',
#  'ShipCity',
#  'ShipRegion',
#  'ShipPostalCode',
#  'ShipCountry']

# %%
df_order = pd.DataFrame(cur.fetchall(), columns = col_names)

# %%
cur.execute('''SELECT *
               FROM OrderDetail;''')
col_names = [x[0] for x in cur.description]
df_details = pd.DataFrame(cur.fetchall(), columns = col_names)
df_details.head()
# Out:
#          Id  OrderId  ProductId  UnitPrice  Quantity  Discount
# 0  10248/11    10248         11       14.0        12       0.0
# 1  10248/42    10248         42        9.8        10       0.0
# 2  10248/72    10248         72       34.8         5       0.0
# 3  10249/14    10249         14       18.6         9       0.0
# 4  10249/51    10249         51       42.4        40       0.0

# %%
df = pd.merge(df_details,df_order, how='outer',left_on='OrderId', right_on='Id')
df.head()
# Out:
#        Id_x  OrderId  ProductId  UnitPrice  Quantity  Discount   Id_y  \
# 0  10248/11    10248         11       14.0        12       0.0  10248
# 1  10248/42    10248         42        9.8        10       0.0  10248
# 2  10248/72    10248         72       34.8         5       0.0  10248
# 3  10249/14    10249         14       18.6         9       0.0  10249
# 4  10249/51    10249         51       42.4        40       0.0  10249
#
#   CustomerId  EmployeeId   OrderDate RequiredDate ShippedDate  ShipVia  \
# 0      VINET           5  2012-07-04   2012-08-01  2012-07-16        3
# 1      VINET           5  2012-07-04   2012-08-01  2012-07-16        3
# 2      VINET           5  2012-07-04   2012-08-01  2012-07-16        3
# 3      TOMSP           6  2012-07-05   2012-08-16  2012-07-10        1
# 4      TOMSP           6  2012-07-05   2012-08-16  2012-07-10        1
#
#    Freight                   ShipName         ShipAddress ShipCity  \
# 0    32.38  Vins et alcools Chevalier  59 rue de l'Abbaye    Reims
# 1    32.38  Vins et alcools Chevalier  59 rue de l'Abbaye    Reims
# 2    32.38  Vins et alcools Chevalier  59 rue de l'Abbaye    Reims
# 3    11.61         Toms Spezialitäten       Luisenstr. 48  Münster
# 4    11.61         Toms Spezialitäten       Luisenstr. 48  Münster
#
#        ShipRegion ShipPostalCode ShipCountry
# 0  Western Europe          51100      France
# 1  Western Europe          51100      France
# 2  Western Europe          51100      France
# 3  Western Europe          44087     Germany
# 4  Western Europe          44087     Germany

# %%
df_order.head()
# Out:
#       Id CustomerId  EmployeeId   OrderDate RequiredDate ShippedDate  ShipVia  \
# 0  10248      VINET           5  2012-07-04   2012-08-01  2012-07-16        3
# 1  10249      TOMSP           6  2012-07-05   2012-08-16  2012-07-10        1
# 2  10250      HANAR           4  2012-07-08   2012-08-05  2012-07-12        2
# 3  10251      VICTE           3  2012-07-08   2012-08-05  2012-07-15        1
# 4  10252      SUPRD           4  2012-07-09   2012-08-06  2012-07-11        2
#
#    Freight                   ShipName           ShipAddress        ShipCity  \
# 0    32.38  Vins et alcools Chevalier    59 rue de l'Abbaye           Reims
# 1    11.61         Toms Spezialitäten         Luisenstr. 48         Münster
# 2    65.83              Hanari Carnes       Rua do Paço, 67  Rio de Janeiro
# 3    41.34       Victuailles en stock    2, rue du Commerce            Lyon
# 4    51.30           Suprêmes délices  Boulevard Tirou, 255       Charleroi
#
#        ShipRegion ShipPostalCode ShipCountry
# 0  Western Europe          51100      France
# 1  Western Europe          44087     Germany
# 2   South America      05454-876      Brazil
# 3  Western Europe          69004      France
# 4  Western Europe         B-6000     Belgium

# %%
ax = sns.barplot(data=df, x ='ShipRegion', y='Quantity', ci=68)
ax.set_xticklabels(ax.get_xticklabels(),rotation=45, ha='right');

# %%
regions = {}
for region_grps in df['ShipRegion'].unique():
    regions[region_grps]= df.groupby('ShipRegion').get_group(region_grps)['Quantity']
regions
# Out:
# {'Western Europe': 0        12
#  1        10
#  2         5
#  3         9
#  4        40
#  8         6
#  9        15
#  10       20
#  11       40
#  12       25
#  13       40
#  17       15
#  18       21
#  19       21
#  20       20
#  21       35
#  22       25
#  23       30
#  29       50
#  30       65
#  31        6
#  34       16
#  35       50
#  36       15
#  37       21
#  43       60
#  44       28
#  45       60
#  46       36
#  49       30
#         ...
#  2042      2
#  2043     30
#  2049     30
#  2050     30
#  2053     10
#  2057     20
#  2058     15
#  2059     18
#  2066     10
#  2069     35
#  2070     20
#  2071     25
#  2082      3
#  2083     21
#  2084      4
#  2106      9
#  2111     40
#  2112     20
#  2113     30
#  2114     20
#  2117      8
#  2118     40
#  2119     22
#  2120    130
#  2124     10
#  2125     30
#  2126      2
#  2127     20
#  2128     20
#  2129     10
#  Name: Quantity, Length: 745, dtype: int64, 'South America': 5       10
#  6       35
#  7       15
#  14      20
#  15      42
#  16      40
#  24      15
#  25      12
#  26      25
#  27       6
#  28      15
#  38      20
#  39      20
#  55      10
#  56       4
#  91      20
#  92      18
#  93      35
#  94       3
#  104     40
#  105     20
#  106     15
#  111     20
#  112     15
#  113     15
#  114     10
#  115     20
#  116     24
#  117      2
#  118     20
#          ..
#  1991     3
#  1992     2
#  1999    35
#  2000    30
#  2044    20
#  2045    24
#  2046    60
#  2047    28
#  2051    15
#  2052     4
#  2063    10
#  2064     4
#  2067    30
#  2068    10
#  2072    10
#  2073    20
#  2074    15
#  2075    15
#  2076    20
#  2077    20
#  2085    30
#  2086    12
#  2087    35
#  2101     4
#  2102    20
#  2107     8
#  2108    36
#  2109    28
#  2115    15
#  2116    10
#  Name: Quantity, Length: 355, dtype: int64, 'Central America': 32      10
#  33       1
#  74      15
#  75      10
#  119     12
#  120     10
#  121      5
#  122      6
#  150     30
#  151     10
#  152      2
#  161      1
#  162      5
#  187      8
#  188     14
#  189     30
#  192     20
#  282     12
#  283      4
#  313     24
#  600     12
#  601     18
#  602     21
#  603     10
#  667     21
#  668      6
#  669     30
#  679     15
#  680     15
#  712      5
#          ..
#  997      3
#  998      5
#  999     10
#  1124     2
#  1125     7
#  1126    21
#  1127    30
#  1128     8
#  1140    30
#  1141     4
#  1142    30
#  1349    10
#  1555    15
#  1556     5
#  1557    20
#  1558    12
#  1596    20
#  1597    20
#  1732    10
#  1733    30
#  1734    10
#  1758     2
#  1759    10
#  1760     7
#  1761    10
#  1927    20
#  1928     4
#  2110    20
#  2121    10
#  2122    20
#  Name: Quantity, Length: 72, dtype: int64, 'North America': 40      12
#  41      15
#  42       2
#  57      60
#  58      20
#  61      24
#  62       6
#  63      40
#  64      24
#  123     18
#  124     15
#  125     15
#  126     21
#  127      6
#  153     25
#  154     25
#  155     30
#  159     10
#  160      3
#  168     10
#  169      5
#  177     40
#  178     30
#  179     25
#  182     10
#  183     70
#  184     20
#  196     21
#  197     70
#  198     30
#          ..
#  2099     4
#  2100    55
#  2103     3
#  2104    42
#  2105    35
#  2130    24
#  2131     4
#  2132     1
#  2133     1
#  2134     1
#  2135     2
#  2136     1
#  2137     2
#  2138     4
#  2139     1
#  2140     2
#  2141     1
#  2142     2
#  2143     1
#  2144     2
#  2145     3
#  2146     3
#  2147     2
#  2148     2
#  2149     2
#  2150     2
#  2151     1
#  2152     2
#  2153     4
#  2154     2
#  Name: Quantity, Length: 427, dtype: int64, 'Northern Europe': 47      35
#  48      25
#  78      16
#  79      15
#  80       8
#  81      25
#  83      12
#  84      20
#  85      30
#  209     25
#  210     50
#  211     35
#  212     30
#  249      8
#  250      9
#  316     36
#  317     18
#  318     15
#  319      7
#  343      6
#  360     28
#  361     15
#  401     60
#  402     30
#  403     35
#  404     14
#  449     50
#  450      2
#  451     36
#  452     35
#          ..
#  1646    21
#  1647    15
#  1656    30
#  1657    30
#  1658    50
#  1705    30
#  1706     6
#  1746    10
#  1747    40
#  1753    20
#  1754    30
#  1755     6
#  1810    25
#  1811    25
#  1812    40
#  1833    12
#  1878    30
#  1879    30
#  1880    10
#  1881    20
#  1892    40
#  1924    50
#  1925    35
#  1926    18
#  1943    60
#  1944    25
#  1945    25
#  1946     6
#  2065    50
#  2123    14
#  Name: Quantity, Length: 143, dtype: int64, 'Scandinavia': 51      12
#  59      30
#  60      25
#  190     30
#  226     10
#  227     10
#  228     40
#  367     15
#  368      6
#  369     12
#  370     15
#  438     20
#  446     20
#  447     10
#  448     20
#  500     15
#  549     20
#  550     50
#  551     25
#  552     30
#  718      8
#  719      5
#  737      8
#  738     10
#  739     30
#  814     15
#  815     14
#  816     24
#  817     30
#  818      6
#          ..
#  1174    10
#  1175     4
#  1176    20
#  1322     5
#  1323    40
#  1324    25
#  1398     3
#  1399    20
#  1400    35
#  1520     2
#  1521     8
#  1522     8
#  1523     9
#  1642    20
#  1643     3
#  1653    12
#  1654    10
#  1655    10
#  1717    12
#  1718    15
#  1719     5
#  1720    12
#  1721    10
#  1722     5
#  1956     2
#  1957    10
#  1981    15
#  1982    18
#  2007    10
#  2008    20
#  Name: Quantity, Length: 70, dtype: int64, 'Southern Europe': 72      12
#  73       6
#  86       1
#  87       6
#  88       4
#  89       6
#  90       2
#  107     10
#  108      3
#  140     30
#  141     20
#  147     40
#  148     30
#  149     15
#  156     10
#  157     10
#  158      5
#  206     24
#  207     16
#  208     50
#  213      9
#  214     40
#  215     10
#  235     18
#  278     10
#  279     20
#  314      5
#  315      5
#  397     10
#  398     18
#          ..
#  1765     5
#  1766     5
#  1793    10
#  1794    40
#  1801    28
#  1814     9
#  1815    40
#  1816     4
#  1821     5
#  1853     2
#  1867    40
#  1960    30
#  1961    10
#  1962    14
#  1966    12
#  1967    18
#  1968     9
#  1969    20
#  1970    10
#  1976    10
#  1977     4
#  1978    20
#  1979     2
#  2009     8
#  2010    10
#  2040     4
#  2088     4
#  2089    10
#  2091    10
#  2092    12
#  Name: Quantity, Length: 137, dtype: int64, 'British Isles': 109     30
#  110      9
#  134     40
#  135     40
#  136     30
#  137     15
#  163     20
#  164     30
#  165      2
#  166     20
#  167      3
#  180     14
#  181     30
#  185     20
#  186      6
#  191     10
#  231      7
#  232     25
#  233      6
#  234     48
#  284     25
#  285     25
#  295     56
#  296     70
#  297     80
#  311     30
#  312      5
#  334     80
#  335     50
#  341     20
#          ..
#  1781    30
#  1802    15
#  1803    21
#  1804    15
#  1813     4
#  1827    50
#  1828    50
#  1901    36
#  1902     8
#  1903    35
#  1908    60
#  1909     6
#  1910    20
#  1983    15
#  1984    16
#  2001     4
#  2002    30
#  2003    12
#  2004    30
#  2005    21
#  2006    50
#  2060    25
#  2061    30
#  2078    40
#  2079    35
#  2080    50
#  2081     3
#  2093    30
#  2094    40
#  2095    30
#  Name: Quantity, Length: 190, dtype: int64, 'Eastern Europe': 336     30
#  337     15
#  957      6
#  958     10
#  959     15
#  1424    10
#  1425     3
#  1426    15
#  1633     3
#  1634     2
#  1713    15
#  1933    12
#  1934     7
#  1935    20
#  1936    30
#  2054    12
#  Name: Quantity, dtype: int64}

# %%
fig, ax=plt.subplots(figsize = (8,5))
for region_grps, grp_data in regions.items():
    sns.distplot(grp_data, label=region_grps, ax=ax)
ax.legend()
ax.set(title ='Quantity by Different Region', ylabel = 'Density');

# %%
for region_grps, grp_data in regions.items():
    idx_outs = find_outliers_z(grp_data)
    print(f'I found {idx_outs.sum()} outliers in {region_grps} using z-scores')
    regions[region_grps] = grp_data[-idx_outs]
# Out:
# I found 14 outliers in Western Europe using z-scores
# I found 5 outliers in South America using z-scores
# I found 1 outliers in Central America using z-scores
# I found 10 outliers in North America using z-scores
# I found 0 outliers in Northern Europe using z-scores
# I found 1 outliers in Scandinavia using z-scores
# I found 1 outliers in Southern Europe using z-scores
# I found 5 outliers in British Isles using z-scores
# I found 0 outliers in Eastern Europe using z-scores

# %%
fig, ax=plt.subplots(figsize = (8,5))
for region_grps, grp_data in regions.items():
    sns.distplot(grp_data, label=region_grps, ax=ax)
ax.legend()
ax.set(title ='Quantity by Different Region', ylabel = 'Density');

# %%
for k,v in regions.items():
    stat,p = stats.normaltest(v)
    print(f"The {k} Normaltest p-value = {round(p,4)}")
# Out:
# The Western Europe Normaltest p-value = 0.0
# The South America Normaltest p-value = 0.0
# The Central America Normaltest p-value = 0.0426
# The North America Normaltest p-value = 0.0
# The Northern Europe Normaltest p-value = 0.0019
# The Scandinavia Normaltest p-value = 0.011
# The Southern Europe Normaltest p-value = 0.0001
# The British Isles Normaltest p-value = 0.0
# The Eastern Europe Normaltest p-value = 0.2396

# %%
data = []
for k,v in regions.items():
    data.append(v)
data[0]
# Out:
# 0       12
# 1       10
# 2        5
# 3        9
# 4       40
# 8        6
# 9       15
# 10      20
# 11      40
# 12      25
# 13      40
# 17      15
# 18      21
# 19      21
# 20      20
# 21      35
# 22      25
# 23      30
# 29      50
# 30      65
# 31       6
# 34      16
# 35      50
# 36      15
# 37      21
# 43      60
# 44      28
# 45      60
# 46      36
# 49      30
#         ..
# 2041     5
# 2042     2
# 2043    30
# 2049    30
# 2050    30
# 2053    10
# 2057    20
# 2058    15
# 2059    18
# 2066    10
# 2069    35
# 2070    20
# 2071    25
# 2082     3
# 2083    21
# 2084     4
# 2106     9
# 2111    40
# 2112    20
# 2113    30
# 2114    20
# 2117     8
# 2118    40
# 2119    22
# 2124    10
# 2125    30
# 2126     2
# 2127    20
# 2128    20
# 2129    10
# Name: Quantity, Length: 731, dtype: int64

# %%
stat,p = stats.levene(*data) 
print(f'Levenes test for equal variance p-value ={round(p,4)} therefore it does not have equal variance.')
# Out:
# Levenes test for equal variance p-value =0.0 therefore it does not have equal variance.

# %%
stat,p = stats.kruskal(*data)
print(f'Kruskal-Wallis t-test p-value ={round(p,4)} therefore the alternative hypothesis is statistically significance.')
# Out:
# Kruskal-Wallis t-test p-value =0.0 therefore the alternative hypothesis is statistically significance.

# %%
df_tukeys = prep_data_for_tukeys(regions)
df_tukeys.head()
df_tukeys.columns = ['ShipRegion','Quantity']

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
model= pairwise_tukeyhsd(df_tukeys['ShipRegion'],df_tukeys['Quantity'])
model.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
ax = sns.barplot(data=df, x = df_tukeys['Quantity'], y= df_tukeys['ShipRegion'], ci=68)
ax.set_xticklabels(ax.get_xticklabels(),rotation=45, ha='right');

# %% [markdown]
# # Hypothesis 4

# %% [markdown]
# > Does the supplier region have a statistically significant effect on the total amount spent?
#
# - $H_0$: The supplier region does not have an effect on the total amount spent.
# - $H_A$: THe supplier region does have an effect on the total amount spent.

# %% [markdown]
# To find the total amount spent on an order we multiply the unit price by the number of items bought.

# %%
df['Total Spent'] = df['UnitPrice'] * df['Quantity']
df
# Out:
#           Id_x  OrderId  ProductId  UnitPrice  Quantity  Discount   Id_y  \
# 0     10248/11    10248         11      14.00        12      0.00  10248
# 1     10248/42    10248         42       9.80        10      0.00  10248
# 2     10248/72    10248         72      34.80         5      0.00  10248
# 3     10249/14    10249         14      18.60         9      0.00  10249
# 4     10249/51    10249         51      42.40        40      0.00  10249
# 5     10250/41    10250         41       7.70        10      0.00  10250
# 6     10250/51    10250         51      42.40        35      0.15  10250
# 7     10250/65    10250         65      16.80        15      0.15  10250
# 8     10251/22    10251         22      16.80         6      0.05  10251
# 9     10251/57    10251         57      15.60        15      0.05  10251
# 10    10251/65    10251         65      16.80        20      0.00  10251
# 11    10252/20    10252         20      64.80        40      0.05  10252
# 12    10252/33    10252         33       2.00        25      0.05  10252
# 13    10252/60    10252         60      27.20        40      0.00  10252
# 14    10253/31    10253         31      10.00        20      0.00  10253
# 15    10253/39    10253         39      14.40        42      0.00  10253
# 16    10253/49    10253         49      16.00        40      0.00  10253
# 17    10254/24    10254         24       3.60        15      0.15  10254
# 18    10254/55    10254         55      19.20        21      0.15  10254
# 19    10254/74    10254         74       8.00        21      0.00  10254
# 20     10255/2    10255          2      15.20        20      0.00  10255
# 21    10255/16    10255         16      13.90        35      0.00  10255
# 22    10255/36    10255         36      15.20        25      0.00  10255
# 23    10255/59    10255         59      44.00        30      0.00  10255
# 24    10256/53    10256         53      26.20        15      0.00  10256
# 25    10256/77    10256         77      10.40        12      0.00  10256
# 26    10257/27    10257         27      35.10        25      0.00  10257
# 27    10257/39    10257         39      14.40         6      0.00  10257
# 28    10257/77    10257         77      10.40        15      0.00  10257
# 29     10258/2    10258          2      15.20        50      0.20  10258
# ...        ...      ...        ...        ...       ...       ...    ...
# 2125  11075/46    11075         46      12.00        30      0.15  11075
# 2126  11075/76    11075         76      18.00         2      0.15  11075
# 2127   11076/6    11076          6      25.00        20      0.25  11076
# 2128  11076/14    11076         14      23.25        20      0.25  11076
# 2129  11076/19    11076         19       9.20        10      0.25  11076
# 2130   11077/2    11077          2      19.00        24      0.20  11077
# 2131   11077/3    11077          3      10.00         4      0.00  11077
# 2132   11077/4    11077          4      22.00         1      0.00  11077
# 2133   11077/6    11077          6      25.00         1      0.02  11077
# 2134   11077/7    11077          7      30.00         1      0.05  11077
# 2135   11077/8    11077          8      40.00         2      0.10  11077
# 2136  11077/10    11077         10      31.00         1      0.00  11077
# 2137  11077/12    11077         12      38.00         2      0.05  11077
# 2138  11077/13    11077         13       6.00         4      0.00  11077
# 2139  11077/14    11077         14      23.25         1      0.03  11077
# 2140  11077/16    11077         16      17.45         2      0.03  11077
# 2141  11077/20    11077         20      81.00         1      0.04  11077
# 2142  11077/23    11077         23       9.00         2      0.00  11077
# 2143  11077/32    11077         32      32.00         1      0.00  11077
# 2144  11077/39    11077         39      18.00         2      0.05  11077
# 2145  11077/41    11077         41       9.65         3      0.00  11077
# 2146  11077/46    11077         46      12.00         3      0.02  11077
# 2147  11077/52    11077         52       7.00         2      0.00  11077
# 2140      RATTC           1  2014-05-06     ...            None       2
# 2141      RATTC           1  2014-05-06     ...            None       2
# 2142      RATTC           1  2014-05-06     ...            None       2
# 2143      RATTC           1  2014-05-06     ...            None       2
# 2144      RATTC           1  2014-05-06     ...            None       2
# 2145      RATTC           1  2014-05-06     ...            None       2
# 2146      RATTC           1  2014-05-06     ...            None       2
# 2147      RATTC           1  2014-05-06     ...            None       2
# 2148      RATTC           1  2014-05-06     ...            None       2
# 2149      RATTC           1  2014-05-06     ...            None       2
# 2150      RATTC           1  2014-05-06     ...            None       2
# 2151      RATTC           1  2014-05-06     ...            None       2
# 2152      RATTC           1  2014-05-06     ...            None       2
# 2153      RATTC           1  2014-05-06     ...            None       2
# 2154      RATTC           1  2014-05-06     ...            None       2
#
#       Freight                    ShipName  \
# 0       32.38   Vins et alcools Chevalier
# 1       32.38   Vins et alcools Chevalier
# 2       32.38   Vins et alcools Chevalier
# 3       11.61          Toms Spezialitäten
# 4       11.61          Toms Spezialitäten
# 5       65.83               Hanari Carnes
# 6       65.83               Hanari Carnes
# 7       65.83               Hanari Carnes
# 8       41.34        Victuailles en stock
# 9       41.34        Victuailles en stock
# 10      41.34        Victuailles en stock
# 11      51.30            Suprêmes délices
# 12      51.30            Suprêmes délices
# 13      51.30            Suprêmes délices
# 14      58.17               Hanari Carnes
# 15      58.17               Hanari Carnes
# 16      58.17               Hanari Carnes
# 17      22.98           Chop-suey Chinese
# 18      22.98           Chop-suey Chinese
# 19      22.98           Chop-suey Chinese
# 20     148.33          Richter Supermarkt
# 21     148.33          Richter Supermarkt
# 22     148.33          Richter Supermarkt
# 23     148.33          Richter Supermarkt
# 24      13.97      Wellington Importadora
# 25      13.97      Wellington Importadora
# 26      81.91            HILARION-Abastos
# 27      81.91            HILARION-Abastos
# 28      81.91            HILARION-Abastos
# 29     140.51                Ernst Handel
# ...       ...                         ...
# 2125     6.19          Richter Supermarkt
# 2126     6.19          Richter Supermarkt
# 2127    38.28                    Bon app'
# 2128    38.28                    Bon app'
# 2129    38.28                    Bon app'
# 2130     8.53  Rattlesnake Canyon Grocery
# 2131     8.53  Rattlesnake Canyon Grocery
# 2132     8.53  Rattlesnake Canyon Grocery
# 2133     8.53  Rattlesnake Canyon Grocery
# 2134     8.53  Rattlesnake Canyon Grocery
# 2135     8.53  Rattlesnake Canyon Grocery
# 2136     8.53  Rattlesnake Canyon Grocery
# 2137     8.53  Rattlesnake Canyon Grocery
# 2138     8.53  Rattlesnake Canyon Grocery
# 2139     8.53  Rattlesnake Canyon Grocery
# 2140     8.53  Rattlesnake Canyon Grocery
# 2141     8.53  Rattlesnake Canyon Grocery
# 2142     8.53  Rattlesnake Canyon Grocery
# 2143     8.53  Rattlesnake Canyon Grocery
# 2144     8.53  Rattlesnake Canyon Grocery
# 2145     8.53  Rattlesnake Canyon Grocery
# 2146     8.53  Rattlesnake Canyon Grocery
# 2147     8.53  Rattlesnake Canyon Grocery
# 2148     8.53  Rattlesnake Canyon Grocery
# 2149     8.53  Rattlesnake Canyon Grocery
#           ShipRegion ShipPostalCode  ShipCountry Total Spent
# 0     Western Europe          51100       France      168.00
# 1     Western Europe          51100       France       98.00
# 2     Western Europe          51100       France      174.00
# 3     Western Europe          44087      Germany      167.40
# 4     Western Europe          44087      Germany     1696.00
# 5      South America      05454-876       Brazil       77.00
# 6      South America      05454-876       Brazil     1484.00
# 7      South America      05454-876       Brazil      252.00
# 8     Western Europe          69004       France      100.80
# 9     Western Europe          69004       France      234.00
# 10    Western Europe          69004       France      336.00
# 11    Western Europe         B-6000      Belgium     2592.00
# 12    Western Europe         B-6000      Belgium       50.00
# 13    Western Europe         B-6000      Belgium     1088.00
# 14     South America      05454-876       Brazil      200.00
# 15     South America      05454-876       Brazil      604.80
# 16     South America      05454-876       Brazil      640.00
# 17    Western Europe           3012  Switzerland       54.00
# 18    Western Europe           3012  Switzerland      403.20
# 19    Western Europe           3012  Switzerland      168.00
# 20    Western Europe           1204  Switzerland      304.00
# 21    Western Europe           1204  Switzerland      486.50
# 22    Western Europe           1204  Switzerland      380.00
# 23    Western Europe           1204  Switzerland     1320.00
# 24     South America      08737-363       Brazil      393.00
# 25     South America      08737-363       Brazil      124.80
# 26     South America           5022    Venezuela      877.50
# 27     South America           5022    Venezuela       86.40
# 28     South America           5022    Venezuela      156.00
# 29    Western Europe           8010      Austria      760.00
# ...              ...            ...          ...         ...
# 2125  Western Europe           1204  Switzerland      360.00
# 2126  Western Europe           1204  Switzerland       36.00
# 2127  Western Europe          13008       France      500.00
# 2128  Western Europe          13008       France      465.00
# 2129  Western Europe          13008       France       92.00
# 2130   North America          87110          USA      456.00
# 2131   North America          87110          USA       40.00
# 2132   North America          87110          USA       22.00
# 2133   North America          87110          USA       25.00
# 2134   North America          87110          USA       30.00
# 2135   North America          87110          USA       80.00
# 2136   North America          87110          USA       31.00
# 2137   North America          87110          USA       76.00
# 2138   North America          87110          USA       24.00
# 2139   North America          87110          USA       23.25
# 2140   North America          87110          USA       34.90
# 2141   North America          87110          USA       81.00
# 2142   North America          87110          USA       18.00
# 2143   North America          87110          USA       32.00
# 2144   North America          87110          USA       36.00
# 2145   North America          87110          USA       28.95
# 2146   North America          87110          USA       36.00
# 2147   North America          87110          USA       14.00
# 2148   North America          87110          USA       48.00
# 2149   North America          87110          USA       68.00
# 2150   North America          87110          USA       66.50
# 2151   North America          87110          USA       17.00
# 2152   North America          87110          USA       30.00
# 2153   North America          87110          USA       31.00
# 2154   North America          87110          USA       26.00
#
# [2155 rows x 21 columns]

# %%
ax = sns.barplot(data=df, x ='ShipRegion', y='Total Spent', ci=68)
ax.set_xticklabels(ax.get_xticklabels(),rotation=45, ha='right');

# %%
regions = {}
for region_grps in df['ShipRegion'].unique():
    regions[region_grps]= df.groupby('ShipRegion').get_group(region_grps)['Total Spent']
regions
# Out:
# {'Western Europe': 0        168.00
#  1         98.00
#  2        174.00
#  3        167.40
#  4       1696.00
#  8        100.80
#  9        234.00
#  10       336.00
#  11      2592.00
#  12        50.00
#  13      1088.00
#  17        54.00
#  18       403.20
#  19       168.00
#  20       304.00
#  21       486.50
#  22       380.00
#  23      1320.00
#  29       760.00
#  2007     180.00
#  2008     120.00
#  Name: Total Spent, Length: 70, dtype: float64,
#  'Southern Europe': 72        43.20
#  73       264.00
#  86         7.30
#  87        21.60
#  88        57.60
#  89       124.20
#  90        31.20
#  107       59.00
#  108       30.00
#  140      408.00
#  141      200.00
#  147      588.00
#  148      504.00
#  149      150.00
#  156      207.00
#  157      262.00
#  158       29.50
#  206      422.40
#  207      249.60
#  208      310.00
#  213      396.00
#  214      672.00
#  215      100.00
#  235      316.80
#  278       36.00
#  279      118.00
#  314       84.00
#  315       52.00
#  397       80.00
#  398      763.20
#           ...
#  1765      47.50
#  1766      90.00
#  1793     190.00
#  1794     560.00
#  1801     560.00
#  1814     146.25
#  1815    2120.00
#  1816      96.00
#  1821     110.00
#  1853      68.00
#  1867     280.00
#  1960    1200.00
#  1961    1237.90
#  1962     196.00
#  1966      54.00
#  1967     342.00
#  1968     306.00
#  1969     600.00
#  1970      45.00
#  1976      90.00
#  1977      56.00
#  1978     190.00
#  1979      25.00
#  2009     500.00
#  2010     530.00
#  2040      60.00
#  2088     136.00
#  2089     130.00
#  2091     328.00
#  2092     180.00
#  Name: Total Spent, Length: 137, dtype: float64,
#  'British Isles': 109      240.00
#  110      239.40
#  134      608.00
#  135      608.00
#  136     1320.00
#  137      591.00
#  163      352.00
#  164      600.00
#  165       22.40
#  166      736.00
#  167       51.60
#  180      156.80
#  181      360.00
#  185      154.00
#  186       86.40
#  191      144.00
#  231      106.40
#  232      250.00
#  233      153.60
#  234     2035.20
#  284       90.00
#  285      390.00
#  295      778.40
#  296      700.00
#  297     2176.00
#  311      864.00
#  312       86.00
#  334      848.00
#  335      860.00
#  341      728.00
#           ...
#  1781     855.00
#  1802      90.00
#  1803     441.00
#  1804     180.00
#  1813     220.00
#  1827    4050.00
#  1828     625.00
#  1901     628.20
#  1902     500.00
#  1903    1120.00
#  1908    1800.00
#  1909     276.00
#  1910     696.00
#  1983     187.50
#  1984     304.00
#  2001     120.00
#  2002    1380.00
#  2003     374.76
#  2004      75.00
#  2005     442.05
#  2006    1075.00
#  2060     450.00
#  2061     640.50
#  2078    1200.00
#  2079     840.00
#  2080    1700.00
#  2081      45.00
#  2093     420.00
#  2094     736.00
#  2095     289.50
#  Name: Total Spent, Length: 190, dtype: float64,
#  'Eastern Europe': 336     300.00
#  337     159.00
#  957     108.00
#  958     190.00
#  959     510.00
#  1424    190.00
#  1425     22.35
#  1426    187.50
#  1633     54.00
#  1634    106.00
#  1713    427.50
#  1933     54.00
#  1934    199.50
#  1935    200.00
#  1936    232.50
#  2054    591.60
#  Name: Total Spent, dtype: float64}

# %%
fig, ax=plt.subplots(figsize = (8,5))
for region_grps, grp_data in regions.items():
    sns.distplot(grp_data, label=region_grps, ax=ax)
ax.legend()
ax.set(title ='Total Spent by Different Regions', ylabel = 'Density');

# %%
for region_grps, grp_data in regions.items():
    idx_outs = find_outliers_z(grp_data)
    print(f'I found {idx_outs.sum()} outliers in {region_grps} using z-scores')
    regions[region_grps] = grp_data[-idx_outs]
# Out:
# I found 11 outliers in Western Europe using z-scores
# I found 2 outliers in South America using z-scores
# I found 1 outliers in Central America using z-scores
# I found 8 outliers in North America using z-scores
# I found 2 outliers in Northern Europe using z-scores
# I found 1 outliers in Scandinavia using z-scores
# I found 3 outliers in Southern Europe using z-scores
# I found 4 outliers in British Isles using z-scores
# I found 0 outliers in Eastern Europe using z-scores

# %%
fig, ax=plt.subplots(figsize = (8,5))
for region_grps, grp_data in regions.items():
    sns.distplot(grp_data, label=region_grps, ax=ax)
ax.legend()
ax.set(title ='Total Spent by Different Regions', ylabel = 'Density');

# %%
for k,v in regions.items():
    stat,p = stats.normaltest(v)
    print(f"The {k} Normaltest p-value = {round(p,4)}")
# Out:
# The Western Europe Normaltest p-value = 0.0
# The South America Normaltest p-value = 0.0
# The Central America Normaltest p-value = 0.0
# The North America Normaltest p-value = 0.0
# The Northern Europe Normaltest p-value = 0.0
# The Scandinavia Normaltest p-value = 0.0
# The Southern Europe Normaltest p-value = 0.0
# The British Isles Normaltest p-value = 0.0
# The Eastern Europe Normaltest p-value = 0.1024

# %%
data = []
for k,v in regions.items():
    data.append(v)
data[0]
# Out:
# 0        168.00
# 1         98.00
# 2        174.00
# 3        167.40
# 4       1696.00
# 8        100.80
# 9        234.00
# 10       336.00
# 11      2592.00
# 12        50.00
# 13      1088.00
# 17        54.00
# 18       403.20
# 19       168.00
# 20       304.00
# 21       486.50
# 22       380.00
# 23      1320.00
# 29       760.00
# 30      1105.00
# 31       153.60
# 34       123.20
# 35       780.00
# 36       591.00
# 37       252.00
# 43       834.00
# 44       100.80
# 45      1242.00
# 46       288.00
# 49       936.00
#          ...
# 2041      92.00
# 2042      14.00
# 2043     645.00
# 2049     570.00
# 2050    1317.00
# 2053     210.00
# 2057     760.00
# 2058     480.00
# 2059     324.00
# 2066      45.00
# 2069    2187.50
# 2070     640.00
# 2071     831.25
# 2082      30.00
# 2083     714.00
# 2084     114.00
# 2106      86.85
# 2111     720.00
# 2112     380.00
# 2113     523.50
# 2114     250.00
# 2117     152.00
# 2118     386.00
# 2119     357.50
# 2124     190.00
# 2125     360.00
# 2126      36.00
# 2127     500.00
# 2128     465.00
# 2129      92.00
# Name: Total Spent, Length: 734, dtype: float64

# %%
stat,p = stats.levene(*data) 
print(f'Levenes test for equal variance p-value ={round(p,4)} therefore it does not have equal variance.')
# Out:
# Levenes test for equal variance p-value =0.0 therefore it does not have equal variance.

# %%
stat,p = stats.kruskal(*data)
print(f'Kruskal-Wallis t-test p-value ={round(p,4)} therefore the alternative hypothesis is statistically significance.')
# Out:
# Kruskal-Wallis t-test p-value =0.0 therefore the alternative hypothesis is statistically significance.

# %%
df_tukeys = prep_data_for_tukeys(regions)
df_tukeys.head()
df_tukeys.columns = ['ShipRegion','Total Spent']

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
model= pairwise_tukeyhsd(df_tukeys['ShipRegion'],df_tukeys['Total Spent'])
model.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
ax = sns.barplot(data=df, x = df_tukeys['Total Spent'], y= df_tukeys['ShipRegion'], ci=68)
ax.set_xticklabels(ax.get_xticklabels(),rotation=45, ha='right');

# %%
#intro - bullet overview with the four questions.
#one slide per questions with results. *bar plots/significance/which one
#recommendations with hypothesis
